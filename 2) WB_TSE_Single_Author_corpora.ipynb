# %%
import pandas as pd
import numpy as np

# %%
#df_main = pd.read_csv("/Users/shashanksingh/Desktop/KENYA_LAW_DATA/METADATA_ANALYSIS/FINAL_DATA/metadata_merged_v8.csv").drop(["Unnamed: 0"], axis = 1)

# %%
#df_main.head()

# %%
df_judges = pd.read_csv("/Users/shashanksingh/Desktop/KENYA_LAW_DATA/working_data_luis/search_engine_judge_names_by_case.csv")

# %%
df_judges = df_judges[df_judges["normalized_name"].notnull()]

# %%
df_judges
# Out:
#         case_id               original_judge_name  \
# 0             1         amraphael mbogholi-msagha
# 1            10                          a b shah
# 2           100  alnashir ramazanali magan visram
# 3         10000      riaga samuel cornelius omolo
# 4         10000               philip kiptoo tunoi
# ...         ...                               ...
# 155881    99995                      oscar angote
# 155882    99996                     lucy waithaka
# 155883    99997                       mumbi ngugi
# 155884    99998              maureen akinyi odero
# 155885    99999          hilary kiplagat chemitei
#
#                          normalized_name          search_engine_judge_name
# 0              amraphael mbogholi-msagha         amraphael mbogholi-msagha
# 1                            a b shah ja           amrittal bhagwanji shah
# 2       alnashir ramazanali magan visram  alnashir ramazanali magan visram
# 3           riaga samuel cornelius omolo      riaga samuel cornelius omolo
# 4                    philip kiptoo tunoi               philip kiptoo tunoi
# ...                                  ...                               ...
# 155881                      oscar angote                      oscar angote
# 155882                     lucy waithaka                     lucy waithaka
# 155883                       mumbi ngugi                       mumbi ngugi
# 155884              maureen akinyi odero              maureen akinyi odero
# 155885          hilary kiplagat chemitei          hilary kiplagat chemitei
#
# [155816 rows x 4 columns]

# %%
df_judges = df_judges.drop_duplicates(subset='case_id', keep=False).reset_index(drop=True)

# %%
len(df_judges)
# Out:
# 118326

# %%
list_judge_names = list(set(list(df_judges["normalized_name"])))

# %%
list_judge_names
# Out:
# ['william ouko',
#  'benard mweresa eboso',
#  'j w mwera j',
#  'alnashir ramazanali magan visram',
#  'norbury dugdale',
#  'w k korir',
#  'mary muthoni gitumbi',
#  'e k usui macharia',
#  'julie oseko',
#  'g m njuguna',
#  'elija ogoti obaga',
#  'none',
#  'antony charo mrima',
#  "bwonwong'a justus momanyi",
#  'r k ondieki',
#  'edward nii adjar torgbor',
#  'm n gicheru',
#  'c obulutsa',
#  'olga akech sewe',
#  'hellen wasilwa seruya',
#  'e malesi',
#  't s luvuga',
#  'nelly awori matheka',
#  'm warsame',
#  's k gacheru',
#  'monica mbaru',
#  'm w wachira',
#  'fred kwasi apaloo',
#  'thande mugure',
#  'ngaah jairus',
#  'mohammed khadhar ibrahim',
#  'george ernest omondi tunya',
#  'm w murage',
#  'eugene cotran',
#  'felix kombo',
#  'edward trevelyan',
#  'judith wanjala',
#  'david maitai rimita',
#  'christine wanjiku meoli',
#  'stella ngali mutuku',
#  'sharad rao',
#  'mwangi njoroge',
#  'milicent akinyi odeny',
#  'c w githua',
#  'washika',
#  'mohamed noor kullow',
#  's ongeri',
#  'mitey j k j',
#  'martin muya',
#  'e juma',
#  'mg mugo j',
#  'dolphina alego snr',
#  'b m ochoi',
#  'mary muhanji kasango',
#  'john mutungi',
#  'janet nzilani mulwa',
#  'h m ng’ang’a',
#  'roselyn naliaka nambuye',
#  'khapoya s benson',
#  'mutitu r m j',
#  'm odero',
#  'william musya musyoka',
#  'r k koech',
#  'mwangi',
#  'kosgei',
#  'g k kimondo',
#  'd k matutu esq',
#  'r odenyo',
#  "kathurima m'inoti",
#  'v o adet',
#  'stewart mwachiru madzayo',
#  'maureen akinyi odero',
#  'robert kipkoech limo',
#  'abdullah',
#  's m mokua',
#  'langat-koech c betty',
#  'rose edwina atieno ougo',
#  'alex george aluri etyang',
#  'james rika',
#  'raj bahadar bhandari',
#  'james aaron makau',
#  'pj ransely j',
#  'abida ali-aroni',
#  'andrew isaac hayanga',
#  'sila munyao',
#  'nyutu',
#  'd n ogoti',
#  'grace a mmasi',
#  'jackson kasanga mulwa',
#  'jonathan bowen havelock',
#  'cecilia wathaiya githua',
#  'mwai',
#  'daniel david ntanda nsereko',
#  'hayanga a i',
#  'gilbert andalya omwitsa',
#  'lawrence peter ouna',
#  'betty rashid',
#  'akua kuenyehia',
#  'jamila mohammed',
#  'joseph william alexander butler-sloss',
#  'akilano molade akiwumi',
#  'enock chirchir cherono',
#  'jeanne wanjiku gacheche',
#  'daniel kiio musinga',
#  'j l a osiemo j',
#  'g p omondi',
#  'stella munai muketi',
#  's k onjoro',
#  'wendy k micheni',
#  'jaswinder singh sehmi',
#  'george martin ongondo',
#  'richard mururu mwongo',
#  'gurbachan singh pall',
#  'linus kassan',
#  'amrittal bhagwanji shah',
#  'samuel william wako wambuzi',
#  'l n mugambi',
#  'philip kiptoo tunoi',
#  'edward muthoga muriithi',
#  'francis gikonyo',
#  'muthoga ca',
#  'joseph raymond otieno masime',
#  'j v o juma',
#  'philip nyamu waki',
#  's r wewa',
#  'a m obura',
#  'j munguti',
#  'cosmas maundu',
#  'r k langat',
#  'norbert okumu',
#  'lucy njora drsc',
#  'chunilal bhagwandas madan',
#  'mohammed abdullahi warsame',
#  'marete d k njagi',
#  'b ombewa',
#  'paul kihara kariuki',
#  'nicholas randa owano ombija',
#  'oscar angote',
#  'bernard chunga',
#  'apondi m',
#  'roseline a oganyo',
#  'james onyiego nyarangi',
#  "anne apondi ong'injo",
#  'said juma chitembwe',
#  'robert mugo mutitu',
#  'david a onyancha',
#  'mandari',
#  'hpg wawaru',
#  'v karanja',
#  'stephen nyangau riechi',
#  'john walter onyango otieno',
#  'lucy waruguru gitari',
#  'c',
#  'david christopher porter',
#  'ang’awa m a',
#  'r n muriuki',
#  'timothy o okello',
#  'd o onyango',
#  'b n olao',
#  'hydfbxbas',
#  'mathews nderi nduma',
#  'l ambasi',
#  'charles yano kimutai',
#  'benjamin patrick kubo',
#  'c k obara',
#  'erastus mwaniki githinji',
#  'james otieno olola',
#  'l k mutai',
#  'r nyakundi',
#  'osiemo j l a',
#  'c a otieno',
#  'a a lakha',
#  'moijo matayia ole keiwua',
#  'y a shikanda',
#  'margaret waringa muigai',
#  'aggrey otsyula muchelule',
#  'abdul majid cockar',
#  'r ougo',
#  'charles pius chemuttut',
#  'of ingutya at wajir',
#  'harold grant platt',
#  'abigail mshila',
#  'rachel biomondo ngetich',
#  'antonina kossy bor',
#  'jane muyoti onyango',
#  'philip john ransley',
#  'joyce nuku khaminwa',
#  'barabara kiprugut tanui',
#  'd a orimba',
#  'dermot joseph sheridan',
#  'malesi kidali',
#  'reuben nyambati nyakundi',
#  'loice chepkemoi komingoi',
#  'a i hussein',
#  'c w meoli',
#  'p ngare gesora',
#  'kuloba r',
#  'susan ndegwa',
#  'hpg',
#  'teresia mumbua matheka',
#  'orenge k i',
#  'w j gichimu',
#  'jairus ngaah',
#  'anthony kaniaru',
#  'pritam singh brar',
#  'd k njagi marate',
#  'lucy nyambura gacheru',
#  'd w mburu',
#  'david shikomera majanja',
#  'nathan shiundu lutta',
#  'kaburu bauni',
#  'roseline pauline vunoro wendoh',
#  'abdulla mustafa',
#  'sankale ole kantai',
#  'joyce adhiambo aluoch',
#  'j k mitey',
#  's o mogute',
#  'p n maina',
#  'g m a ong’ondo',
#  'a c a ong’injo',
#  'j gandani',
#  'j kiarie',
#  'b k tanui',
#  'l kimaru',
#  'jackton boma ojwang',
#  'margaret njoki mwangi',
#  'daniel kennedy sultani aganyanya',
#  'mwera j w j',
#  'n njagi',
#  'david kenani maraga',
#  'byram ongaya',
#  't m mwangi',
#  'boaz nathan olao',
#  'a b shah ja',
#  'lydia awino achode',
#  'ruth nekoye sitati',
#  'kalpana hasmukhrai rawal',
#  'justus kituku',
#  'c o nyawiri',
#  "hedwig imbosa ong'udi",
#  'onesmus ndambuthi makau',
#  's o oguk',
#  'm munyao sila',
#  'b p kub0',
#  'anne omollo',
#  'mathew guy muli',
#  'mwilu',
#  'j o magori',
#  'o a angote',
#  's o temu',
#  'joseph vitalis odero juma',
#  's m mungai',
#  'stephen kibunja',
#  'ernest fredrick aragon',
#  'tutui',
#  'musyoka j',
#  'b ochieng',
#  'w a juma',
#  'g n wakahiu',
#  'e a obina',
#  'florence nyaguthii muchemi',
#  'r walekhwa',
#  'trail',
#  'c k njai',
#  'benard ochieng ondego',
#  'j k kingori',
#  'jacqueline kamau',
#  'onguto joseph louis omondi',
#  'james n mwaniki',
#  'jemutai grace kemei',
#  'm o wambani',
#  'hellen amolo omondi',
#  'charles gitonga mbogo',
#  'l m wachira',
#  'g w ngenye â€“ macharia',
#  'b mosiria',
#  'pk rugut',
#  'etyang a g a j',
#  'james otieno odek',
#  'patel v v j',
#  'agnes kalekye murgor',
#  't a odera',
#  'joseph gregory nyamu',
#  'lucy waithaka',
#  'james patrick trainor',
#  'james wakiaga',
#  'surrender kumar sachdeva',
#  'daniel ogolla',
#  'peter john hewett',
#  'onesmus kimweli mutungi',
#  'richard otieno kwach',
#  'christine atieno ochieng',
#  'tank j',
#  'v k kiptoon',
#  'isaac charles cheskaki wambilyangah',
#  'j n muniu',
#  'sheikh mohammed amin',
#  'm m nafula',
#  "c o ong'udi",
#  "samson odhiambo okong'o",
#  'p m muilu',
#  't obutu',
#  'effie owuor',
#  'caroline kemei',
#  'francis tuiyott',
#  'william mbaya',
#  'lesiit jessie w',
#  'ndwiga',
#  'david kipyegomen kemei',
#  'juma j v o',
#  'fatuma sichale',
#  'd',
#  's okongôçöo',
#  'e muriuki nyagah',
#  'abdulrasul ahmed lakha',
#  'cecil henry ethelwood miller',
#  "j k ng'arng'ar",
#  'm onkoba',
#  'luka kiprotich kimaru',
#  'john mwangi gachuhi',
#  'leonard njagi',
#  'mary clausina oundo',
#  'p n areri',
#  'richard charles namasaka kuloba',
#  'esther nyambura maina',
#  'james frank shields',
#  'zakayo richard chesoni',
#  'samwel ndungu mukunya',
#  'l n waithaka',
#  'm k mwangi',
#  'nzioki wa makau',
#  'joseph mbalu mutava',
#  'm sudi',
#  'wilson nkunja kaberia',
#  'tanui b k arap j',
#  'w kagendo',
#  's lamu',
#  'fidulhussein esmailji abdullah',
#  'nelson jorum abuodha',
#  "a g a etyang'",
#  'grace lidembu nzioka',
#  's k mutai',
#  'wilfrida adhiambo okwany',
#  'c n ndegwa',
#  'mayamba c a',
#  'elena g nderitu',
#  'mwongo',
#  'b r kipyegon',
#  'patrick omwenga kiage',
#  'patrick j okwaro otieno',
#  's n riechi',
#  'alister arthur kneller',
#  'radido stephen okiyo',
#  'riaga samuel cornelius omolo',
#  'mumbi ngugi',
#  'sarah chibai ondeyo',
#  'kunyuk tito',
#  'weldon kipyegon korir',
#  'george matatia abaleka dulu',
#  'muga apondi',
#  'kiarie waweru kiarie',
#  '0',
#  'na',
#  'farah s m amin',
#  'john wycliffe mwera',
#  'j j masiga',
#  'george benedict maina kariuki',
#  'doreen mulekyo',
#  'm wakahora',
#  'w k chepseba',
#  'lucy ngima mbugua',
#  'hazel wandere',
#  'j m mutungi',
#  'stephen gatembu kairu',
#  'derek schofield',
#  'linnet ndolo',
#  "emmanuel okello o'kubasu",
#  'alfred henry simpson',
#  'w ouko',
#  "john muting'a mativo",
#  'peter muchoki njoroge',
#  'b j ndeda',
#  'george vincent odunga',
#  'n',
#  's n makila',
#  'abdallah j',
#  'm amin j',
#  'njeri thuku',
#  'rewa',
#  'k sambu',
#  'anthony k mwicigi',
#  'william shirley deverell',
#  'peter nyagaka areri',
#  'johnson evan gicheru',
#  "'s' at nairobi)",
#  'p j ransley judge',
#  "ndung'u h n",
#  'pauline nyamweya',
#  's m shitubi',
#  'eric john ewen law',
#  'wanjiru karanja',
#  'temba a sitati',
#  'john luka osiemo',
#  'mulwa j k',
#  'maureen atieno onyango',
#  'e obaga',
#  'eric kennedy okumu ogola',
#  'm kasera',
#  'aaron g ringera',
#  'hilary kiplagat chemitei',
#  'martha a nanzushi',
#  'gideon p mbito',
#  'john amonde mango',
#  'ekaterina trendafilova',
#  'philomena mbete mwilu',
#  'amraphael mbogholi-msagha',
#  'lucy mwihaki njuguna',
#  'hannah magondi okwengu',
#  'khamoni j m j',
#  'johnson kiptonui mitey',
#  'ezra o awino',
#  'e a nyaloti',
#  'murugi geteria mugo',
#  'kanyi kimondo',
#  'samwel odhiambo oguk',
#  'lilian nabwire mutende',
#  'andayi w francis',
#  'abdul rauf samnakay',
#  'isaac lenaola',
#  "mary atieno ang'awa",
#  'roseline lagat-korir',
#  'john nyabuto onyiego',
#  'john henry sydney todd',
#  'm i g moranga',
#  'l t lewa',
#  'milton stephen asike makhandia',
#  'p gichohi',
#  'paul kiptenai kimisoy arap birech',
#  'alan robin winston hancox',
#  'stephen murugu githinji',
#  'e wanjala',
#  'r n kimingi',
#  'e k usui',
#  'hatari peter george waweru',
#  'felix makoyo',
#  'mutungi charles kariuki',
#  'tom mbaluto',
#  'b mararo',
#  'bernard kasavuli',
#  's m s soita',
#  'joseph kiplagat sergon',
#  'martha karambu koome',
#  'dorah o chepkwony',
#  'cheruto c kipkorir',
#  'jessie wanjiku lessit',
#  'm mutuku',
#  'a k mokoross',
#  'n a owino',
#  'kenneth d potter',
#  'judge',
#  'beatrice thuranira jaden',
#  'antony ombwayo',
#  "anthony ndung'u kimani",
#  'joseph raphael karanja',
#  'mitei j',
#  'samuel elikana ondari bosire',
#  'ransley p j',
#  'asenath nyaboke ongeri',
#  'patrick john kamau',
#  'leslie gerald eyre harris',
#  'j k sergon',
#  'fred andago ochieng',
#  's n abuya',
#  'e n maina',
#  'thripsisa wanjiku cherere',
#  'festus azangalala',
#  'nagillah chrispin beda',
#  'gilbert shikwe',
#  'dalmas omondi ohungo',
#  'kennedy a bidali',
#  'vinubhai vithalbhai patel',
#  'william kipsiro tuiyot',
#  'pamela mwikali tutui',
#  'l n mesa',
#  'r o kwach ja',
#  'enock chacha mwita',
#  'bauni k j',
#  'jesse nyagah njagi',
#  'p mayova',
#  'of kenya',
#  "a b mong'are",
#  'a k kaniaru',
#  'm l nabibya',
#  'abdulhalim h athman',
#  'roselyne ekirapa aburili',
#  'john micheal khamoni',
#  'daniel ogola ogembo',
#  'alfred mabeya',
#  'mathew john anyara emukule',
#  'yuvinalis maronga angima',
#  't w murigi',
#  'kamau pj j',
#  'evans w muleka',
#  'joel mwaura ngugi']

# %%
from pathlib import Path
main_dir = Path("/u/home/i/iacir21/myscratch")
xlsx_path = main_dir / "train_test_set" / "metadata_merged_v15.xlsx"
df_2 = pd.read_excel(xlsx_path)

# %%
if "normalized_judges" in df_2.columns:
    print("Column exists!")
else:
    print("Column not found.")
# Out:
# Column exists!

# %%
df_judges = pd.read_csv("/u/home/i/iacir21/myscratch/train_test_set/judge_train_caseids.csv")

# %%
# Assume df_judges is the judge-level table you showed
df_expanded = (
    df_judges.assign(train_case_ids=df_judges["train_case_ids"].astype(str).str.split(";"))
             .explode("train_case_ids")
             .reset_index(drop=True)
)

# Make sure case IDs are strings (same type as in df_2)
df_expanded["train_case_ids"] = df_expanded["train_case_ids"].str.strip()

# %%
cols_to_keep = ["judge(s)", "normalized_judges", "length_of_judgement", "case_id"]
df_2_sub = df_2[cols_to_keep].copy()
df_2_sub["case_id"] = df_2_sub["case_id"].astype(str).str.strip()

# %%
train_ids = set(df_expanded["train_case_ids"])
df_filtered = df_2_sub[df_2_sub["case_id"].isin(train_ids)].copy()

# %%
df_3 = pd.read_csv("/u/home/i/iacir21/myscratch/train_test_set/median_year_judges.csv")

df_final = df_filtered.merge(
    df_3, 
    on="judge(s)", 
    how="left"   # keeps all rows in df_filtered, adds matching columns from df_3
)

# %%
# Basic save
df_final.to_csv("/u/home/i/iacir21/myscratch/replication/judge_normalized.csv", index=False)

# %%
df_final
# Out:
#                       judge(s)        normalized_judges  length_of_judgement  \
# 0            james aaron makau        james aaron makau                  519
# 1             pauline nyamweya         pauline nyamweya                  972
# 2        lucy nyambura gacheru    lucy nyambura gacheru                 2014
# 3      samson odhiambo okong'o  samson odhiambo okong'o                 4317
# 4      margaret waringa muigai  margaret waringa muigai                 1067
# ...                        ...                      ...                  ...
# 82976       antonina kossy bor       antonina kossy bor                 1402
# 82977              mumbi ngugi              mumbi ngugi                 2054
# 82978   teresia mumbua matheka   teresia mumbua matheka                  657
# 82979          stephen kibunja          stephen kibunja                  734
# 82980    samwel ndungu mukunya    samwel ndungu mukunya                  415
#
#       case_id  median_year  eligible_docs  train_docs
# 0      132434       2015.0            732         451
# 1       83775       2014.0           1230         731
# 2       98131       2015.0            990         539
# 3      106493       2013.0           1010         620
# 4      141502       2014.0            816         432
# ...       ...          ...            ...         ...
# 82976  150750       2014.0            443         247
# 82977   98728       2014.0            667         404
# 82978  169222       2015.0            468         252
# 82979  122263       2014.0            831         441
# 82980   96628       2013.0            411         290
#
# [82981 rows x 7 columns]

# %%
list_judge_names=['william ouko',
 'benard mweresa eboso',
 'j w mwera j',
 'alnashir ramazanali magan visram',
 'norbury dugdale',
 'w k korir',
 'mary muthoni gitumbi',
 'e k usui macharia',
 'julie oseko',
 'g m njuguna',
 'elija ogoti obaga',
 'none',
 'antony charo mrima',
 "bwonwong'a justus momanyi",
 'r k ondieki',
 'edward nii adjar torgbor',
 'm n gicheru',
 'c obulutsa',
 'olga akech sewe',
 'hellen wasilwa seruya',
 'e malesi',
 't s luvuga',
 'nelly awori matheka',
 'm warsame',
 's k gacheru',
 'monica mbaru',
 'm w wachira',
 'fred kwasi apaloo',
 'thande mugure',
 'ngaah jairus',
 'mohammed khadhar ibrahim',
 'george ernest omondi tunya',
 'm w murage',
 'eugene cotran',
 'felix kombo',
 'edward trevelyan',
 'judith wanjala',
 'david maitai rimita',
 'christine wanjiku meoli',
 'stella ngali mutuku',
 'sharad rao',
 'mwangi njoroge',
 'milicent akinyi odeny',
 'c w githua',
 'washika',
 'mohamed noor kullow',
 's ongeri',
 'mitey j k j',
 'martin muya',
 'e juma',
 'mg mugo j',
 'dolphina alego snr',
 'b m ochoi',
 'mary muhanji kasango',
 'john mutungi',
 'janet nzilani mulwa',
 'h m ng’ang’a',
 'roselyn naliaka nambuye',
 'khapoya s benson',
 'mutitu r m j',
 'm odero',
 'william musya musyoka',
 'r k koech',
 'mwangi',
 'kosgei',
 'g k kimondo',
 'd k matutu esq',
 'r odenyo',
 "kathurima m'inoti",
 'v o adet',
 'stewart mwachiru madzayo',
 'maureen akinyi odero',
 'robert kipkoech limo',
 'abdullah',
 's m mokua',
 'langat-koech c betty',
 'rose edwina atieno ougo',
 'alex george aluri etyang',
 'james rika',
 'raj bahadar bhandari',
 'james aaron makau',
 'pj ransely j',
 'abida ali-aroni',
 'andrew isaac hayanga',
 'sila munyao',
 'nyutu',
 'd n ogoti',
 'grace a mmasi',
 'jackson kasanga mulwa',
 'jonathan bowen havelock',
 'cecilia wathaiya githua',
 'mwai',
 'daniel david ntanda nsereko',
 'hayanga a i',
 'gilbert andalya omwitsa',
 'lawrence peter ouna',
 'betty rashid',
 'akua kuenyehia',
 'jamila mohammed',
 'joseph william alexander butler-sloss',
 'akilano molade akiwumi',
 'enock chirchir cherono',
 'jeanne wanjiku gacheche',
 'daniel kiio musinga',
 'j l a osiemo j',
 'g p omondi',
 'stella munai muketi',
 's k onjoro',
 'wendy k micheni',
 'jaswinder singh sehmi',
 'george martin ongondo',
 'richard mururu mwongo',
 'gurbachan singh pall',
 'linus kassan',
 'amrittal bhagwanji shah',
 'samuel william wako wambuzi',
 'l n mugambi',
 'philip kiptoo tunoi',
 'edward muthoga muriithi',
 'francis gikonyo',
 'muthoga ca',
 'joseph raymond otieno masime',
 'j v o juma',
 'philip nyamu waki',
 's r wewa',
 'a m obura',
 'j munguti',
 'cosmas maundu',
 'r k langat',
 'norbert okumu',
 'lucy njora drsc',
 'chunilal bhagwandas madan',
 'mohammed abdullahi warsame',
 'marete d k njagi',
 'b ombewa',
 'paul kihara kariuki',
 'nicholas randa owano ombija',
 'oscar angote',
 'bernard chunga',
 'apondi m',
 'roseline a oganyo',
 'james onyiego nyarangi',
 "anne apondi ong'injo",
 'said juma chitembwe',
 'robert mugo mutitu',
 'david a onyancha',
 'mandari',
 'hpg wawaru',
 'v karanja',
 'stephen nyangau riechi',
 'john walter onyango otieno',
 'lucy waruguru gitari',
 'c',
 'david christopher porter',
 'ang’awa m a',
 'r n muriuki',
 'timothy o okello',
 'd o onyango',
 'b n olao',
 'hydfbxbas',
 'mathews nderi nduma',
 'l ambasi',
 'charles yano kimutai',
 'benjamin patrick kubo',
 'c k obara',
 'erastus mwaniki githinji',
 'james otieno olola',
 'l k mutai',
 'r nyakundi',
 'osiemo j l a',
 'c a otieno',
 'a a lakha',
 'moijo matayia ole keiwua',
 'y a shikanda',
 'margaret waringa muigai',
 'aggrey otsyula muchelule',
 'abdul majid cockar',
 'r ougo',
 'charles pius chemuttut',
 'of ingutya at wajir',
 'harold grant platt',
 'abigail mshila',
 'rachel biomondo ngetich',
 'antonina kossy bor',
 'jane muyoti onyango',
 'philip john ransley',
 'joyce nuku khaminwa',
 'barabara kiprugut tanui',
 'd a orimba',
 'dermot joseph sheridan',
 'malesi kidali',
 'reuben nyambati nyakundi',
 'loice chepkemoi komingoi',
 'a i hussein',
 'c w meoli',
 'p ngare gesora',
 'kuloba r',
 'susan ndegwa',
 'hpg',
 'teresia mumbua matheka',
 'orenge k i',
 'w j gichimu',
 'jairus ngaah',
 'anthony kaniaru',
 'pritam singh brar',
 'd k njagi marate',
 'lucy nyambura gacheru',
 'd w mburu',
 'david shikomera majanja',
 'nathan shiundu lutta',
 'kaburu bauni',
 'roseline pauline vunoro wendoh',
 'abdulla mustafa',
 'sankale ole kantai',
 'joyce adhiambo aluoch',
 'j k mitey',
 's o mogute',
 'p n maina',
 'g m a ong’ondo',
 'a c a ong’injo',
 'j gandani',
 'j kiarie',
 'b k tanui',
 'l kimaru',
 'jackton boma ojwang',
 'margaret njoki mwangi',
 'daniel kennedy sultani aganyanya',
 'mwera j w j',
 'n njagi',
 'david kenani maraga',
 'byram ongaya',
 't m mwangi',
 'boaz nathan olao',
 'a b shah ja',
 'lydia awino achode',
 'ruth nekoye sitati',
 'kalpana hasmukhrai rawal',
 'justus kituku',
 'c o nyawiri',
 "hedwig imbosa ong'udi",
 'onesmus ndambuthi makau',
 's o oguk',
 'm munyao sila',
 'b p kub0',
 'anne omollo',
 'mathew guy muli',
 'mwilu',
 'j o magori',
 'o a angote',
 's o temu',
 'joseph vitalis odero juma',
 's m mungai',
 'stephen kibunja',
 'ernest fredrick aragon',
 'tutui',
 'musyoka j',
 'b ochieng',
 'w a juma',
 'g n wakahiu',
 'e a obina',
 'florence nyaguthii muchemi',
 'r walekhwa',
 'trail',
 'c k njai',
 'benard ochieng ondego',
 'j k kingori',
 'jacqueline kamau',
 'onguto joseph louis omondi',
 'james n mwaniki',
 'jemutai grace kemei',
 'm o wambani',
 'hellen amolo omondi',
 'charles gitonga mbogo',
 'l m wachira',
 'g w ngenye â€“ macharia',
 'b mosiria',
 'pk rugut',
 'etyang a g a j',
 'james otieno odek',
 'patel v v j',
 'agnes kalekye murgor',
 't a odera',
 'joseph gregory nyamu',
 'lucy waithaka',
 'james patrick trainor',
 'james wakiaga',
 'surrender kumar sachdeva',
 'daniel ogolla',
 'peter john hewett',
 'onesmus kimweli mutungi',
 'richard otieno kwach',
 'christine atieno ochieng',
 'tank j',
 'v k kiptoon',
 'isaac charles cheskaki wambilyangah',
 'j n muniu',
 'sheikh mohammed amin',
 'm m nafula',
 "c o ong'udi",
 "samson odhiambo okong'o",
 'p m muilu',
 't obutu',
 'effie owuor',
 'caroline kemei',
 'francis tuiyott',
 'william mbaya',
 'lesiit jessie w',
 'ndwiga',
 'david kipyegomen kemei',
 'juma j v o',
 'fatuma sichale',
 'd',
 's okongôçöo',
 'e muriuki nyagah',
 'abdulrasul ahmed lakha',
 'cecil henry ethelwood miller',
 "j k ng'arng'ar",
 'm onkoba',
 'luka kiprotich kimaru',
 'john mwangi gachuhi',
 'leonard njagi',
 'mary clausina oundo',
 'p n areri',
 'richard charles namasaka kuloba',
 'esther nyambura maina',
 'james frank shields',
 'zakayo richard chesoni',
 'samwel ndungu mukunya',
 'l n waithaka',
 'm k mwangi',
 'nzioki wa makau',
 'joseph mbalu mutava',
 'm sudi',
 'wilson nkunja kaberia',
 'tanui b k arap j',
 'w kagendo',
 's lamu',
 'fidulhussein esmailji abdullah',
 'nelson jorum abuodha',
 "a g a etyang'",
 'grace lidembu nzioka',
 's k mutai',
 'wilfrida adhiambo okwany',
 'c n ndegwa',
 'mayamba c a',
 'elena g nderitu',
 'mwongo',
 'b r kipyegon',
 'patrick omwenga kiage',
 'patrick j okwaro otieno',
 's n riechi',
 'alister arthur kneller',
 'radido stephen okiyo',
 'riaga samuel cornelius omolo',
 'mumbi ngugi',
 'sarah chibai ondeyo',
 'kunyuk tito',
 'weldon kipyegon korir',
 'george matatia abaleka dulu',
 'muga apondi',
 'kiarie waweru kiarie',
 '0',
 'na',
 'farah s m amin',
 'john wycliffe mwera',
 'j j masiga',
 'george benedict maina kariuki',
 'doreen mulekyo',
 'm wakahora',
 'w k chepseba',
 'lucy ngima mbugua',
 'hazel wandere',
 'j m mutungi',
 'stephen gatembu kairu',
 'derek schofield',
 'linnet ndolo',
 "emmanuel okello o'kubasu",
 'alfred henry simpson',
 'w ouko',
 "john muting'a mativo",
 'peter muchoki njoroge',
 'b j ndeda',
 'george vincent odunga',
 'n',
 's n makila',
 'abdallah j',
 'm amin j',
 'njeri thuku',
 'rewa',
 'k sambu',
 'anthony k mwicigi',
 'william shirley deverell',
 'peter nyagaka areri',
 'johnson evan gicheru',
 "'s' at nairobi)",
 'p j ransley judge',
 "ndung'u h n",
 'pauline nyamweya',
 's m shitubi',
 'eric john ewen law',
 'wanjiru karanja',
 'temba a sitati',
 'john luka osiemo',
 'mulwa j k',
 'maureen atieno onyango',
 'e obaga',
 'eric kennedy okumu ogola',
 'm kasera',
 'aaron g ringera',
 'hilary kiplagat chemitei',
 'martha a nanzushi',
 'gideon p mbito',
 'john amonde mango',
 'ekaterina trendafilova',
 'philomena mbete mwilu',
 'amraphael mbogholi-msagha',
 'lucy mwihaki njuguna',
 'hannah magondi okwengu',
 'khamoni j m j',
 'johnson kiptonui mitey',
 'ezra o awino',
 'e a nyaloti',
 'murugi geteria mugo',
 'kanyi kimondo',
 'samwel odhiambo oguk',
 'lilian nabwire mutende',
 'andayi w francis',
 'abdul rauf samnakay',
 'isaac lenaola',
 "mary atieno ang'awa",
 'roseline lagat-korir',
 'john nyabuto onyiego',
 'john henry sydney todd',
 'm i g moranga',
 'l t lewa',
 'milton stephen asike makhandia',
 'p gichohi',
 'paul kiptenai kimisoy arap birech',
 'alan robin winston hancox',
 'stephen murugu githinji',
 'e wanjala',
 'r n kimingi',
 'e k usui',
 'hatari peter george waweru',
 'felix makoyo',
 'mutungi charles kariuki',
 'tom mbaluto',
 'b mararo',
 'bernard kasavuli',
 's m s soita',
 'joseph kiplagat sergon',
 'martha karambu koome',
 'dorah o chepkwony',
 'cheruto c kipkorir',
 'jessie wanjiku lessit',
 'm mutuku',
 'a k mokoross',
 'n a owino',
 'kenneth d potter',
 'judge',
 'beatrice thuranira jaden',
 'antony ombwayo',
 "anthony ndung'u kimani",
 'joseph raphael karanja',
 'mitei j',
 'samuel elikana ondari bosire',
 'ransley p j',
 'asenath nyaboke ongeri',
 'patrick john kamau',
 'leslie gerald eyre harris',
 'j k sergon',
 'fred andago ochieng',
 's n abuya',
 'e n maina',
 'thripsisa wanjiku cherere',
 'festus azangalala',
 'nagillah chrispin beda',
 'gilbert shikwe',
 'dalmas omondi ohungo',
 'kennedy a bidali',
 'vinubhai vithalbhai patel',
 'william kipsiro tuiyot',
 'pamela mwikali tutui',
 'l n mesa',
 'r o kwach ja',
 'enock chacha mwita',
 'bauni k j',
 'jesse nyagah njagi',
 'p mayova',
 'of kenya',
 "a b mong'are",
 'a k kaniaru',
 'm l nabibya',
 'abdulhalim h athman',
 'roselyne ekirapa aburili',
 'john micheal khamoni',
 'daniel ogola ogembo',
 'alfred mabeya',
 'mathew john anyara emukule',
 'yuvinalis maronga angima',
 't w murigi',
 'kamau pj j',
 'evans w muleka',
 'joel mwaura ngugi']

# %%
unique_judges_df = set(df_final["normalized_judges"].unique())
unique_judges_list = set(list_judge_names)

# %%
# in list_judge_names but not in df_judges["judge(s)"]
only_in_list = unique_judges_list - unique_judges_df  

# in df_judges["judge(s)"] but not in list_judge_names
only_in_df = unique_judges_df - unique_judges_list  

# intersection (common judges in both)
common = unique_judges_list & unique_judges_df

# %%
print("Only in list_judge_names:", only_in_list)
# Out:
# Only in list_judge_names: {'g w ngenye â€“ macharia', 'ekaterina trendafilova', 'na', 'akua kuenyehia', 'daniel david ntanda nsereko', 'apondi m'}

# %%
print("Only in df_judges['judge(s)']:", only_in_df)
# Out:
# Only in df_judges['judge(s)']: {nan, 'hon. a.d. wako - senior resident kadhi', 'a. d. wako senior resident kadhi', 'hon. idris n. nyaboga resident kadhi homabay kadhi court', 'b.kimemia               -          chairman-signed.  r.mwambura          –          member-signed.  p.swanya                 -          member-signed.', 'dick waweru (chairman) prof. kiarie mwaura (member) aden noor ali (member) betty chepng’etich bii (member) moses parantai (member) betty bii (member)', 'a.ishaq hussein  senior resident kadhi', 'b. kimemia   -  chairman      f. terer  - deputy chairman   r. mwambura  -  member     p. gichuki  -   member', 'dick waweru   chairman  prof. kiarie mwaura  member  betty chepng’etich bii  member', 'hon. idris n. nyaboga resident kadhi', 'mursal m sizi kadhi', 'dick waweru  chairman prof. kiarie mwaura member  moses parantai member  aden noor ali  member betty chepng’etich bii  member', 'dick waweru   chairman     prof. kiarie mwaura  member     moses parantai   member     aden noor ali   member     betty chepng’etich bii  member', 'hillary sigei  (member)  moses sande makhandia  (member) peter mungai  (member)', 'b.kimemia         -      chairman-signed.  r.mwambura      –    member-signed.  p.swanya          -        member-signed.', 'hon. adan i. tullu  senior resident kadhi', 'dick waweru - chairman  prof. kiarie mwaura - member     moses parantai - member aden noor ali - member', 'waigi kamau - chairperson  elyas abdi– member  dr pius mutisya -member  harun yusuf    -  member', 'm o lwanga desma nungo paul ngotho adelaide mbithi', 'kyalo mbobu paul ngotho desma nungo', 'jamal i. opacha kadhi', 'dick waweru (chairman) prof. kiarie mwaura (member) moses parantai (member)', 'b.kimemia           -      chairman-signed  r.mwambura       –     member-signed  p.swanya             -        member-signed', 'b. kimemia          -        chairman-signed  r. mwambura      –        member-signed  p. swanya            -        member-signed', 'hon a .d. wako.', 'dick waweru (chairman) prof. kiarie mwaura (member) aden noor ali (member)', 'hon. a. d. wako  senior resident kadhi', 'dick waweru     chairman', 'joseph m. were – chairman          ocharo kebira – member  annette gikuya – member', 'prof. kiarie mwaura  member    moses parantai   member    aden noor ali   member    betty chepng’etich bii  member', 'dick waweru   chairman    moses parantai   member    aden noor ali   member', 'felix kombo  senior principal magistrate', 'hon. d. s. ratori principal kadhi', 'hon a .d. wako - senior resident kadhi', 'b.kimemia  - chairman-signed.  r.mwambura  – member-signed.  p.swanya  - member-signed.', '.kimemia               -          chairman-signed.  r.mwambura          –          member-signed.  p.swanya                 -          member-signed.', 'hon. d. s. ratori', 'b.kimemia               -          chairman-signed  r.mwambura          –          member-signed  p.swanya                 -          member-signed', 'm. mohamed sambu', 'b.kimemia-chairman-signed.  r.mwambura–member-signed. p.swanya -member-signed.', 'm o lwanga paul ngotho adelaide mbithi', 'galgalo adan - senior resident kadhi', 'mursal.m.sizi-kadhi', 'dick waweru   chairman    prof. kiarie mwaura  member     moses parantai   member', 'adan i. tullu senior resident kadhi', 'b. kimemia          -        chairman-signed.  r. mwambura      –        member-signed.  p. swanya            -        member-signed.', 'a.i. hhussein -senior resident kadhi', 'dick waweru chairman prof. kiarie mwaura member moses parantai member aden noor ali member', 'hon ln mugambi (mr) cm', 'dick waweru   chairman prof. kiarie mwaura  member aden noor ali   member moses parantai  member betty chepng’etich bii   member', 'ishaq aj senior resident kadhi', 'hon. a. d. wako', 'b.kimemia           -        chairman-signed.  r.mwambura  –  member-signed.  p.swanya  -   member-signed.', 'said hamisi bedzenga -hon. principal kadhi', 'hon. abdulhalim h. athman principal kadhi', 'b.kimemia-ch ...

# %%
print("Common:", common)
# Out:
# Common: {'hayanga a i', 't m mwangi', 'samuel william wako wambuzi', 'd k matutu esq', 'mohammed abdullahi warsame', "'s' at nairobi)", 'r ougo', 'd a orimba', 'w a juma', 'a k mokoross', 'francis tuiyott', 'alister arthur kneller', 'jonathan bowen havelock', 'said juma chitembwe', 'jamila mohammed', 's k onjoro', 'mwangi njoroge', 'o a angote', 'p m muilu', 'm w murage', 'harold grant platt', 'w j gichimu', 'd', 'alfred mabeya', 'c w meoli', 'olga akech sewe', 'mathew john anyara emukule', 'abdul rauf samnakay', 'v k kiptoon', 'trail', 'gurbachan singh pall', 'william kipsiro tuiyot', 'milton stephen asike makhandia', 'e muriuki nyagah', 'martin muya', 'mitey j k j', 'judge', "kathurima m'inoti", 'l k mutai', 'mitei j', 'kenneth d potter', 'b p kub0', 'charles gitonga mbogo', 's r wewa', 'd k njagi marate', 'joyce nuku khaminwa', 'p j ransley judge', 'linus kassan', 'john mutungi', 's o oguk', 's n riechi', 'charles pius chemuttut', 'paul kihara kariuki', 'nicholas randa owano ombija', 'hilary kiplagat chemitei', 'isaac charles cheskaki wambilyangah', 'e n maina', 'enock chirchir cherono', 'joseph mbalu mutava', 'daniel ogolla', 'david christopher porter', 'james otieno olola', 'martha karambu koome', 's okongôçöo', 'l ambasi', 'samuel elikana ondari bosire', 'j gandani', 'hydfbxbas', 'norbert okumu', "john muting'a mativo", 'lucy waithaka', 'e k usui', 'r n kimingi', 'langat-koech c betty', 'onguto joseph louis omondi', 'c n ndegwa', 'b j ndeda', 'rose edwina atieno ougo', 'martha a nanzushi', 'james wakiaga', 'gideon p mbito', 'yuvinalis maronga angima', 'akilano molade akiwumi', 'onesmus kimweli mutungi', 'v o adet', 'lucy waruguru gitari', 'g k kimondo', 'r o kwach ja', 'v karanja', 'christine atieno ochieng', 'm w wachira', "emmanuel okello o'kubasu", 'vinubhai vithalbhai patel', 'alnashir ramazanali magan visram', 's o mogute', 'mulwa j k', 'mathews nderi nduma', 'stella ngali mutuku', 'elija ogoti obaga', 'ndwiga', 'jackton boma ojwang', 'j n muniu', 'philomena mbete mwilu', 'philip kiptoo tunoi', 'ransley p j', 'p mayova', 'barabara kiprugut tanui', 'judith wanjala', 'stella munai muketi', 'sila munyao', 'james patrick trainor', '0', 'j v o juma', 'b ochieng', 'peter nyagaka areri', 'e wanjala', 'radido stephen okiyo', 'k sambu', 'dalmas omondi ohungo', 'philip nyamu waki', 'boaz nathan olao', 'joyce adhiambo aluoch', 'mwera j w j', 'g m a ong’ondo', 'amrittal bhagwanji shah', 'lucy njora drsc', 'benard mweresa eboso', 'roseline a oganyo', 'marete d k njagi', 'john wycliffe mwera', 'jairus ngaah', 'etyang a g a j', "c o ong'udi", 'esther nyambura maina', 'temba a sitati', 'p n areri', 'mary clausina oundo', 's k mutai', 'of kenya', 'r k ondieki', 'jacqueline kamau', 'kosgei', 'j m mutungi', 'riaga samuel cornelius omolo', 'j k kingori', 'richard charles namasaka kuloba', 'sankale ole kantai', 'e malesi', 'justus kituku', 'wilson nkunja kaberia', 'khamoni j m j', 'e juma', 'hazel wandere', 'beatrice thuranira jaden', 'joseph vitalis odero juma', 'sarah chibai ondeyo', 'ngaah jairus', 'mwai', 'jackson kasanga mulwa', 'c w githua', 'c', 'felix makoyo', 'of ingutya at wajir', 'j kiarie', 'd n ogoti', 'muthoga ca', 'n a owino', 'nelly awori matheka', 'jane muyoti onyango', 'rachel biomondo ngetich', 'john nyabuto onyiego', 'christine wanjiku meoli', 'oscar angote', 'sharad rao', 'c obulutsa', 'surrender kumar sachdeva', "a g a etyang'", 'edward nii adjar torgbor', 'david shikomera majanja', 'm m nafula', 'samwel odhiambo oguk', 'abigail mshila', 'b n olao', 'edward trevelyan', 'loice chepkemoi komingoi', 'stephen nyangau riechi', 'joseph william alexander butler-sloss', 'kuloba r', 'mohammed khadhar ibrahim', 'fred kwasi apaloo', 'c a otieno', 'b ombewa', 'susan ndegwa', 'c k njai', 'william shirley deverell', 'james rika', 'enock chacha mwita', 'muga apondi', 's ongeri', 'lawrence peter ouna', 'erastus mwaniki githinji', 'wendy k micheni', 'stephen murugu githinji', 'nathan shiundu lutta', 'francis gikonyo', 'philip john  ...

# %%
root_dir = "/u/home/i/iacir21/myscratch/train_test_set/judgements_txt_train"
target_dir = "/u/home/i/iacir21/myscratch/replication/judges_corpus"

# %%
import os
from tqdm import tqdm

# %%
for judge in tqdm(list_judge_names):
    
    df_temp = df_final[df_final["normalized_judges"] == judge]
    list_ids = list(set(list(df_temp["case_id"])))
    
    for case_id in list_ids:
        root_path = os.path.join(root_dir, str(case_id) + ".txt")
        target_path = os.path.join(target_dir, judge)
        
        if not os.path.exists(target_path):
            os.makedirs(target_path)
            
        
        f = open(root_path,"r").read()
        
        file_path = os.path.join(target_path, str(case_id) + ".txt")
        
        g = open(file_path,"w+")
        g.write(f)
# Out:
# 100% 504/504 [08:38<00:00,  1.03s/it]

# %%
# Count how many unique normalized_judge values exist
num_unique_judges = df_final["normalized_judges"].nunique()
print("Number of unique normalized judges:", num_unique_judges)
# Out:
# Number of unique normalized judges: 578

# %%
import os
import pandas as pd

base_dir = "/u/home/i/iacir21/myscratch/replication/judges_corpus"   # replace with your actual path

judge_data = []

# Loop over each judge folder
for judge_folder in os.listdir(base_dir):
    judge_path = os.path.join(base_dir, judge_folder)
    
    if os.path.isdir(judge_path):
        total_words = 0
        num_cases_v2 = 0
        
        # Loop over each .txt file inside the judge's folder
        for file_name in os.listdir(judge_path):
            if file_name.endswith(".txt"):
                file_path = os.path.join(judge_path, file_name)
                with open(file_path, "r", encoding="utf-8", errors="ignore") as f:
                    text = f.read()
                    total_words += len(text.split())
                    num_cases_v2 += 1
        
        judge_data.append([judge_folder, total_words, num_cases])

# Convert to DataFrame
df_tokens = pd.DataFrame(judge_data, columns=["judge_name", "num_tokens", "num_cases_v2"])

print(df_tokens.head())
# Out:
#         judge_name  num_tokens  num_cases_v2
# 0  's' at nairobi)        3003             0
# 1                0        1986             0
# 2        a a lakha         699             0
# 3     a b mong'are         317             0
# 4      a b shah ja        7750             0

# %%
df_tokens
# Out:
#                    judge_name  num_tokens  num_cases_v2
# 0             's' at nairobi)        3003             0
# 1                           0        1986             0
# 2                   a a lakha         699             0
# 3                a b mong'are         317             0
# 4                 a b shah ja        7750             0
# ..                        ...         ...           ...
# 493  william shirley deverell       48533             0
# 494     wilson nkunja kaberia        7141             0
# 495              y a shikanda       16114             0
# 496  yuvinalis maronga angima      524763             0
# 497    zakayo richard chesoni       31668             0
#
# [498 rows x 3 columns]

# %%
df_final
# Out:
#                       judge(s)        normalized_judges  length_of_judgement  \
# 0            james aaron makau        james aaron makau                  519
# 1             pauline nyamweya         pauline nyamweya                  972
# 2        lucy nyambura gacheru    lucy nyambura gacheru                 2014
# 3      samson odhiambo okong'o  samson odhiambo okong'o                 4317
# 4      margaret waringa muigai  margaret waringa muigai                 1067
# ...                        ...                      ...                  ...
# 82976       antonina kossy bor       antonina kossy bor                 1402
# 82977              mumbi ngugi              mumbi ngugi                 2054
# 82978   teresia mumbua matheka   teresia mumbua matheka                  657
# 82979          stephen kibunja          stephen kibunja                  734
# 82980    samwel ndungu mukunya    samwel ndungu mukunya                  415
#
#       case_id  median_year  eligible_docs  train_docs
# 0      132434       2015.0            732         451
# 1       83775       2014.0           1230         731
# 2       98131       2015.0            990         539
# 3      106493       2013.0           1010         620
# 4      141502       2014.0            816         432
# ...       ...          ...            ...         ...
# 82976  150750       2014.0            443         247
# 82977   98728       2014.0            667         404
# 82978  169222       2015.0            468         252
# 82979  122263       2014.0            831         441
# 82980   96628       2013.0            411         290
#
# [82981 rows x 7 columns]

# %%
df_thresh = df_tokens[df_tokens["num_tokens"]>=50000]

# %%
len(df_tokens[df_tokens["num_tokens"]>=250000])
# Out:
# 153

# %%
df_thresh
# Out:
#                    judge_name  num_tokens  num_cases_v2
# 11            aaron g ringera       76309             0
# 19            abida ali-aroni      417870             0
# 20             abigail mshila      426766             0
# 21   aggrey otsyula muchelule      657514             0
# 23     akilano molade akiwumi       64406             0
# ..                        ...         ...           ...
# 488  wilfrida adhiambo okwany      883215             0
# 489    william kipsiro tuiyot       74072             0
# 491     william musya musyoka     1724065             0
# 492              william ouko      465681             0
# 496  yuvinalis maronga angima      524763             0
#
# [196 rows x 3 columns]

# %%
df_thresh.to_csv("/u/home/i/iacir21/myscratch/replication/df_thresh_via.csv", index=False)

# %%
**************************************************************************************************

# %%
df_new
# Out:
#                                 judge gender  tokens  cases
# 0                        william ouko  ['M']  841265    877
# 1                benard mweresa eboso  ['M']  442803    236
# 2                         j w mwera j  ['M']   32947     27
# 3    alnashir ramazanali magan visram  ['M']  581694    512
# 4                     norbury dugdale  ['M']    2570      1
# ..                                ...    ...     ...    ...
# 499          yuvinalis maronga angima  ['M']  444956    262
# 500                        t w murigi  ['F']    2782      1
# 501                        kamau pj j  ['M']    2496      5
# 502                    evans w muleka  ['M']    6434      3
# 503                 joel mwaura ngugi  ['M']  814452    354
#
# [504 rows x 4 columns]

# %%
len(df_new[df_new["tokens"]>=250000])
# Out:
# 160

# %%
len(df_new[(df_new["tokens"]>=250000) & (df_new["gender"]=="['F']")])
# Out:
# 67

# %%
df_new[(df_new["tokens"]>=250000) & (df_new["gender"]=="['F']")]
# Out:
#                          judge gender   tokens  cases
# 6         mary muthoni gitumbi  ['F']   838755    623
# 18             olga akech sewe  ['F']  1039166    407
# 19       hellen wasilwa seruya  ['F']  1899674   1138
# 22         nelly awori matheka  ['F']   639133    461
# 25                monica mbaru  ['F']  2231298    775
# ..                         ...    ...      ...    ...
# 454      jessie wanjiku lessit  ['F']  1741387    968
# 460   beatrice thuranira jaden  ['F']   961920   1000
# 474  thripsisa wanjiku cherere  ['F']   574626    506
# 476     nagillah chrispin beda  ['F']   309710    293
# 494   roselyne ekirapa aburili  ['F']  3463528    764
#
# [67 rows x 4 columns]

# %%
df_thresh = df_new[df_new["tokens"]>=50000]

# %%
df_thresh = df_thresh.reset_index(drop=True)

# %%
df_thresh
# Out:
#                                 judge gender   tokens  cases
# 0                        william ouko  ['M']   841265    877
# 1                benard mweresa eboso  ['M']   442803    236
# 2    alnashir ramazanali magan visram  ['M']   581694    512
# 3                mary muthoni gitumbi  ['F']   838755    623
# 4                   elija ogoti obaga  ['M']  1020921    934
# ..                                ...    ...      ...    ...
# 210              john micheal khamoni  ['M']   748028    466
# 211                     alfred mabeya  ['M']  1883797   1042
# 212        mathew john anyara emukule  ['M']  1877197    909
# 213          yuvinalis maronga angima  ['M']   444956    262
# 214                 joel mwaura ngugi  ['M']   814452    354
#
# [215 rows x 4 columns]

# %%
df_thresh.to_csv("/Users/shashanksingh/Desktop/GloVe/judges_corpus/df_thresh.csv")

# %%
df_temp = df_thresh.sort_values(["judge"])

# %%
df_temp = df_temp.reset_index(drop=True)

# %%
df_temp[:50]
# Out:
#                                judge gender   tokens  cases
# 0                        a i hussein  ['M']    50990     35
# 1                    aaron g ringera  ['M']   151630     62
# 2                abdulhalim h athman  ['M']    62141     52
# 3             abdulrasul ahmed lakha  ['M']    51772     78
# 4                    abida ali-aroni  ['F']   572904    483
# 5                     abigail mshila  ['F']   685048    451
# 6           aggrey otsyula muchelule  ['M']   941053   1063
# 7               agnes kalekye murgor  ['F']    53221     35
# 8             akilano molade akiwumi  ['M']    87126     49
# 9           alex george aluri etyang  ['M']   171047     96
# 10                     alfred mabeya  ['M']  1883797   1042
# 11            alister arthur kneller  ['M']    54300     16
# 12  alnashir ramazanali magan visram  ['M']   581694    512
# 13         amraphael mbogholi-msagha  ['M']   908958   1127
# 14           amrittal bhagwanji shah  ['M']   123217    119
# 15              andrew isaac hayanga  ['M']   174354    163
# 16              anne apondi ong'injo  ['F']   323177    292
# 17                       anne omollo  ['F']   959444    741
# 18                   anthony kaniaru  ['M']   551414    339
# 19            anthony ndung'u kimani  ['M']   510444    322
# 20                antonina kossy bor  ['F']   374104    269
# 21                antony charo mrima  ['M']  1228833    506
# 22                    antony ombwayo  ['M']  1511940    742
# 23            asenath nyaboke ongeri  ['F']   228933    104
# 24           barabara kiprugut tanui  ['F']    83548     64
# 25          beatrice thuranira jaden  ['F']   961920   1000
# 26              benard mweresa eboso  ['M']   442803    236
# 27             benjamin patrick kubo  ['M']   479310    263
# 28                  boaz nathan olao  ['M']  1275714    770
# 29         bwonwong'a justus momanyi  ['M']   496629    433
# 30                      byram ongaya  ['M']  1643947   1167
# 31                        c w githua  ['F']    75789     26
# 32                         c w meoli  ['F']    64740     49
# 33           cecilia wathaiya githua  ['F']   854441    416
# 34             charles gitonga mbogo  ['M']   201357    131
# 35            charles pius chemuttut  ['M']   216549    134
# 36              charles yano kimutai  ['M']   479082    278
# 37          christine atieno ochieng  ['F']   596483    290
# 38           christine wanjiku meoli  ['F']  1361684    714
# 39              dalmas omondi ohungo  ['M']   403453    279
# 40  daniel kennedy sultani aganyanya  ['M']   399367    276
# 41               daniel kiio musinga  ['M']  1451904   1009
# 42                  david a onyancha  ['M']  1169881    830
# 43               david kenani maraga  ['M']   683926    694
# 44            david kipyegomen kemei  ['M']   943646    538
# 45           david shikomera majanja  ['M']  3246665   1904
# 46                 dorah o chepkwony  ['F']   312550    139
# 47           edward muthoga muriithi  ['M']  1877210    626
# 48                       effie owuor  ['F']    69441     88
# 49                 elija ogoti obaga  ['M']  1020921    934

# %%
df_temp[50:100]
# Out:
#                                   judge   gender   tokens  cases
# 50             emmanuel okello o'kubasu    ['M']   235527    209
# 51                   enock chacha mwita    ['M']   981431    279
# 52               enock chirchir cherono    ['M']   220077    152
# 53             erastus mwaniki githinji    ['M']   434016    304
# 54             eric kennedy okumu ogola    ['M']  2134064    942
# 55                esther nyambura maina    ['F']   655962    443
# 56                       farah s m amin    ['F']   440377    171
# 57                    festus azangalala    ['M']  1265838    944
# 58           florence nyaguthii muchemi    ['F']  1270137    952
# 59                      francis gikonyo    ['M']  2554526   1017
# 60                      francis tuiyott    ['M']  1414878    637
# 61                  fred andago ochieng    ['M']  2328783   1370
# 62                          g k kimondo    ['M']    69831     33
# 63                          g n wakahiu    ['M']   146249      5
# 64              g w ngenye â€“ macharia    ['F']  1656331    903
# 65        george benedict maina kariuki    ['M']   516284    552
# 66                george martin ongondo    ['M']   155891    137
# 67          george matatia abaleka dulu    ['M']  2046121   1485
# 68                george vincent odunga    ['M']  9681426   1686
# 69                       gideon p mbito    ['M']    74531     57
# 70                 grace lidembu nzioka    ['F']   592174    211
# 71               hannah magondi okwengu    ['F']  1349917   1064
# 72           hatari peter george waweru    ['M']  1451539   1562
# 73                hedwig imbosa ong'udi    ['F']  1322219    897
# 74                  hellen amolo omondi    ['F']  1432902    803
# 75                hellen wasilwa seruya    ['F']  1899674   1138
# 76             hilary kiplagat chemitei    ['F']   859824    836
# 77  isaac charles cheskaki wambilyangah    ['M']    68954     72
# 78                        isaac lenaola    ['M']  2832331   1213
# 79                          j m mutungi    ['M']    54826     37
# 80                jackson kasanga mulwa    ['M']   113005    153
# 81                  jackton boma ojwang    ['M']  2178741    748
# 82                     jacqueline kamau    ['F']  1862321    718
# 83                         jairus ngaah    ['M']  1414666    563
# 84                    james aaron makau    ['M']  1720895    656
# 85                    james otieno odek    ['M']    53440     27
# 86                   james otieno olola    ['M']   584926    323
# 87                           james rika    ['M']  1816348   1008
# 88                        james wakiaga    ['M']   716672    541
# 89                      jamila mohammed    ['F']    50649     28
# 90                  jane muyoti onyango    ['F']   390643    227
# 91                  janet nzilani mulwa    ['F']   868357    530
# 92              jeanne wanjiku gacheche    ['F']   323611    262
# 93                  jemutai grace kemei    ['F']   768628    359
# 94                   jesse nyagah njagi  ['UNK']   187721     82
# 95                jessie wanjiku lessit    ['F']  1741387    968
# 96                    joel mwaura ngugi    ['M']   814452    354
# 97                     john luka osiemo    ['M']   455191    653
# 98                 john micheal khamoni    ['M']   748028    466
# 99                 john muting'a mativo    ['M']  2186891    513

# %%
df_temp[100:150]
# Out:
#                               judge gender   tokens  cases
# 100                    john mutungi  ['M']  1567136    632
# 101            john nyabuto onyiego  ['M']   360138    191
# 102      john walter onyango otieno  ['M']   402377    214
# 103             john wycliffe mwera  ['M']   782664    565
# 104         jonathan bowen havelock  ['M']  1323364    391
# 105            joseph gregory nyamu  ['M']   562872    205
# 106          joseph kiplagat sergon  ['M']  2904611   2717
# 107             joseph mbalu mutava  ['M']   203095    110
# 108          joseph raphael karanja  ['M']  1174166    749
# 109           joyce adhiambo aluoch  ['F']   305259    225
# 110             joyce nuku khaminwa  ['F']   748476   1083
# 111                    kaburu bauni  ['M']   240188    408
# 112        kalpana hasmukhrai rawal  ['F']   813994    512
# 113                   kanyi kimondo  ['M']   980010    535
# 114            kiarie waweru kiarie  ['M']   342337    373
# 115                   leonard njagi  ['M']   766674    588
# 116                 lesiit jessie w  ['F']   316914    257
# 117          lilian nabwire mutende  ['F']  1238600   1033
# 118                    linnet ndolo  ['F']  1091457    903
# 119        loice chepkemoi komingoi  ['F']   234300    211
# 120            lucy mwihaki njuguna  ['F']  1137684    668
# 121               lucy ngima mbugua  ['F']   492331    507
# 122           lucy nyambura gacheru  ['F']  1745632    773
# 123                   lucy waithaka  ['F']  1288399    694
# 124            lucy waruguru gitari  ['F']   565940    263
# 125           luka kiprotich kimaru  ['M']  3342490   2237
# 126              lydia awino achode  ['F']  1226216    760
# 127                   m munyao sila  ['M']  1951375   1048
# 128                         m odero  ['F']   117931    124
# 129                marete d k njagi  ['M']  1055456    568
# 130           margaret njoki mwangi  ['F']   759099    309
# 131         margaret waringa muigai  ['F']  1176118    652
# 132            martha karambu koome  ['F']  1230406   1033
# 133                     martin muya  ['M']   435748    543
# 134             mary atieno ang'awa  ['F']  1067310   1044
# 135             mary clausina oundo  ['F']   471829    156
# 136            mary muhanji kasango  ['F']  3068248   2435
# 137            mary muthoni gitumbi  ['F']   838755    623
# 138      mathew john anyara emukule  ['M']  1877197    909
# 139             mathews nderi nduma  ['M']  1573465   1143
# 140            maureen akinyi odero  ['F']  1262411   1038
# 141          maureen atieno onyango  ['F']  2129228   1021
# 142                       mg mugo j  ['F']    65530     64
# 143           milicent akinyi odeny  ['F']   448894    230
# 144  milton stephen asike makhandia  ['M']  2344410   1340
# 145             mohamed noor kullow  ['M']   109402    152
# 146      mohammed abdullahi warsame  ['M']   710036    271
# 147        mohammed khadhar ibrahim  ['M']   823861    531
# 148                    monica mbaru  ['F']  2231298    775
# 149                     muga apondi  ['M']   323103    307

# %%
df_thresh[:50]
# Out:
#                                judge gender   tokens  cases
# 0                       william ouko  ['M']   841265    877
# 1               benard mweresa eboso  ['M']   442803    236
# 2   alnashir ramazanali magan visram  ['M']   581694    512
# 3               mary muthoni gitumbi  ['F']   838755    623
# 4                  elija ogoti obaga  ['M']  1020921    934
# 5                 antony charo mrima  ['M']  1228833    506
# 6          bwonwong'a justus momanyi  ['M']   496629    433
# 7                    olga akech sewe  ['F']  1039166    407
# 8              hellen wasilwa seruya  ['F']  1899674   1138
# 9                nelly awori matheka  ['F']   639133    461
# 10                      monica mbaru  ['F']  2231298    775
# 11                     thande mugure  ['F']   389965    198
# 12          mohammed khadhar ibrahim  ['M']   823861    531
# 13           christine wanjiku meoli  ['F']  1361684    714
# 14               stella ngali mutuku  ['F']   936396    536
# 15                        sharad rao  ['M']    53743      2
# 16                    mwangi njoroge  ['M']   700752    448
# 17             milicent akinyi odeny  ['F']   448894    230
# 18                        c w githua  ['F']    75789     26
# 19               mohamed noor kullow  ['M']   109402    152
# 20                       martin muya  ['M']   435748    543
# 21                         mg mugo j  ['F']    65530     64
# 22              mary muhanji kasango  ['F']  3068248   2435
# 23                      john mutungi  ['M']  1567136    632
# 24               janet nzilani mulwa  ['F']   868357    530
# 25           roselyn naliaka nambuye  ['F']  2348655    530
# 26                           m odero  ['F']   117931    124
# 27             william musya musyoka  ['M']  1870479   1756
# 28                       g k kimondo  ['M']    69831     33
# 29              maureen akinyi odero  ['F']  1262411   1038
# 30              robert kipkoech limo  ['M']   843459    393
# 31           rose edwina atieno ougo  ['F']  1421513    799
# 32          alex george aluri etyang  ['M']   171047     96
# 33                        james rika  ['M']  1816348   1008
# 34                 james aaron makau  ['M']  1720895    656
# 35                   abida ali-aroni  ['F']   572904    483
# 36              andrew isaac hayanga  ['M']   174354    163
# 37             jackson kasanga mulwa  ['M']   113005    153
# 38           jonathan bowen havelock  ['M']  1323364    391
# 39           cecilia wathaiya githua  ['F']   854441    416
# 40                   jamila mohammed  ['F']    50649     28
# 41            akilano molade akiwumi  ['M']    87126     49
# 42            enock chirchir cherono  ['M']   220077    152
# 43           jeanne wanjiku gacheche  ['F']   323611    262
# 44               daniel kiio musinga  ['M']  1451904   1009
# 45             george martin ongondo  ['M']   155891    137
# 46             richard mururu mwongo  ['M']   521816    167
# 47           amrittal bhagwanji shah  ['M']   123217    119
# 48               philip kiptoo tunoi  ['M']    66777    107
# 49           edward muthoga muriithi  ['M']  1877210    626

# %%
df_thresh[50:100]
# Out:
#                                judge gender   tokens  cases
# 50                   francis gikonyo  ['M']  2554526   1017
# 51                 philip nyamu waki  ['M']   463868    269
# 52        mohammed abdullahi warsame  ['M']   710036    271
# 53                  marete d k njagi  ['M']  1055456    568
# 54               paul kihara kariuki  ['M']   232820    186
# 55       nicholas randa owano ombija  ['M']   443336    342
# 56                      oscar angote  ['M']  1934941   1461
# 57              anne apondi ong'injo  ['F']   323177    292
# 58               said juma chitembwe  ['M']  1602285   1078
# 59                  david a onyancha  ['M']  1169881    830
# 60            stephen nyangau riechi  ['M']   257345    148
# 61        john walter onyango otieno  ['M']   402377    214
# 62              lucy waruguru gitari  ['F']   565940    263
# 63               mathews nderi nduma  ['M']  1573465   1143
# 64              charles yano kimutai  ['M']   479082    278
# 65             benjamin patrick kubo  ['M']   479310    263
# 66          erastus mwaniki githinji  ['M']   434016    304
# 67                james otieno olola  ['M']   584926    323
# 68           margaret waringa muigai  ['F']  1176118    652
# 69          aggrey otsyula muchelule  ['M']   941053   1063
# 70                            r ougo  ['F']    73026     45
# 71            charles pius chemuttut  ['M']   216549    134
# 72                    abigail mshila  ['F']   685048    451
# 73           rachel biomondo ngetich  ['F']   192122    135
# 74                antonina kossy bor  ['F']   374104    269
# 75               jane muyoti onyango  ['F']   390643    227
# 76               philip john ransley  ['M']   209093    236
# 77               joyce nuku khaminwa  ['F']   748476   1083
# 78           barabara kiprugut tanui  ['F']    83548     64
# 79          reuben nyambati nyakundi  ['M']  1247276    361
# 80          loice chepkemoi komingoi  ['F']   234300    211
# 81                       a i hussein  ['M']    50990     35
# 82                         c w meoli  ['F']    64740     49
# 83            teresia mumbua matheka  ['F']   543368    271
# 84                      jairus ngaah  ['M']  1414666    563
# 85                   anthony kaniaru  ['M']   551414    339
# 86             lucy nyambura gacheru  ['F']  1745632    773
# 87           david shikomera majanja  ['M']  3246665   1904
# 88                      kaburu bauni  ['M']   240188    408
# 89    roseline pauline vunoro wendoh  ['F']  2302463   1520
# 90             joyce adhiambo aluoch  ['F']   305259    225
# 91               jackton boma ojwang  ['M']  2178741    748
# 92             margaret njoki mwangi  ['F']   759099    309
# 93  daniel kennedy sultani aganyanya  ['M']   399367    276
# 94               david kenani maraga  ['M']   683926    694
# 95                      byram ongaya  ['M']  1643947   1167
# 96                  boaz nathan olao  ['M']  1275714    770
# 97                lydia awino achode  ['F']  1226216    760
# 98                ruth nekoye sitati  ['F']  2807448   1353
# 99          kalpana hasmukhrai rawal  ['F']   813994    512

# %%
df_thresh[100:150]
# Out:
#                                    judge gender   tokens  cases
# 100                hedwig imbosa ong'udi  ['F']  1322219    897
# 101              onesmus ndambuthi makau  ['M']  1480993    964
# 102                        m munyao sila  ['M']  1951375   1048
# 103                          anne omollo  ['F']   959444    741
# 104                           o a angote  ['M']    86543     36
# 105                      stephen kibunja  ['M']   901375    692
# 106                          g n wakahiu  ['M']   146249      5
# 107           florence nyaguthii muchemi  ['F']  1270137    952
# 108                     jacqueline kamau  ['F']  1862321    718
# 109           onguto joseph louis omondi  ['M']  1002581    298
# 110                  jemutai grace kemei  ['F']   768628    359
# 111                  hellen amolo omondi  ['F']  1432902    803
# 112                charles gitonga mbogo  ['M']   201357    131
# 113              g w ngenye â€“ macharia  ['F']  1656331    903
# 114                    james otieno odek  ['M']    53440     27
# 115                 agnes kalekye murgor  ['F']    53221     35
# 116                 joseph gregory nyamu  ['M']   562872    205
# 117                        lucy waithaka  ['F']  1288399    694
# 118                        james wakiaga  ['M']   716672    541
# 119              onesmus kimweli mutungi  ['M']   264144    242
# 120             christine atieno ochieng  ['F']   596483    290
# 121  isaac charles cheskaki wambilyangah  ['M']    68954     72
# 122              samson odhiambo okong'o  ['M']  2113439    852
# 123                          effie owuor  ['F']    69441     88
# 124                      francis tuiyott  ['M']  1414878    637
# 125                      lesiit jessie w  ['F']   316914    257
# 126               david kipyegomen kemei  ['M']   943646    538
# 127                          s okongôçöo  ['M']   101507     35
# 128               abdulrasul ahmed lakha  ['M']    51772     78
# 129                luka kiprotich kimaru  ['M']  3342490   2237
# 130                        leonard njagi  ['M']   766674    588
# 131                  mary clausina oundo  ['F']   471829    156
# 132      richard charles namasaka kuloba  ['M']   200295     59
# 133                esther nyambura maina  ['F']   655962    443
# 134                samwel ndungu mukunya  ['M']   396409    423
# 135                      nzioki wa makau  ['M']  1121417    730
# 136                  joseph mbalu mutava  ['M']   203095    110
# 137                 nelson jorum abuodha  ['M']   916326    717
# 138                 grace lidembu nzioka  ['F']   592174    211
# 139             wilfrida adhiambo okwany  ['F']  1161283    538
# 140              patrick j okwaro otieno  ['M']   828131    452
# 141               alister arthur kneller  ['M']    54300     16
# 142                 radido stephen okiyo  ['M']  1462218   1288
# 143         riaga samuel cornelius omolo  ['M']   117560    148
# 144                          mumbi ngugi  ['F']  2116971    590
# 145                weldon kipyegon korir  ['M']  1702834    670
# 146          george matatia abaleka dulu  ['M']  2046121   1485
# 147                          muga apondi  ['M']   323103    307
# 148                 kiarie waweru kiarie  ['M']   342337    373
# 149                                   na    NaN  1176754    920

# %%
df_thresh[150:200]
# Out:
#                               judge   gender   tokens  cases
# 150                  farah s m amin    ['F']   440377    171
# 151             john wycliffe mwera    ['M']   782664    565
# 152   george benedict maina kariuki    ['M']   516284    552
# 153               lucy ngima mbugua    ['F']   492331    507
# 154                     j m mutungi    ['M']    54826     37
# 155                    linnet ndolo    ['F']  1091457    903
# 156        emmanuel okello o'kubasu    ['M']   235527    209
# 157                          w ouko    ['M']    54948     55
# 158            john muting'a mativo    ['M']  2186891    513
# 159           peter muchoki njoroge    ['M']  1306398   1389
# 160           george vincent odunga    ['M']  9681426   1686
# 161                               n  ['UNK']    69487     60
# 162        william shirley deverell    ['M']    69110     48
# 163                pauline nyamweya    ['F']  2781157   1132
# 164                 wanjiru karanja    ['F']   311084    400
# 165                john luka osiemo    ['M']   455191    653
# 166          maureen atieno onyango    ['F']  2129228   1021
# 167        eric kennedy okumu ogola    ['M']  2134064    942
# 168                 aaron g ringera    ['M']   151630     62
# 169        hilary kiplagat chemitei    ['F']   859824    836
# 170                  gideon p mbito    ['M']    74531     57
# 171           philomena mbete mwilu    ['F']   233861    206
# 172       amraphael mbogholi-msagha    ['M']   908958   1127
# 173            lucy mwihaki njuguna    ['F']  1137684    668
# 174          hannah magondi okwengu    ['F']  1349917   1064
# 175             murugi geteria mugo    ['F']   426183    338
# 176                   kanyi kimondo    ['M']   980010    535
# 177            samwel odhiambo oguk    ['M']    79796     55
# 178          lilian nabwire mutende    ['F']  1238600   1033
# 179                   isaac lenaola    ['M']  2832331   1213
# 180             mary atieno ang'awa    ['F']  1067310   1044
# 181            roseline lagat-korir    ['F']   366132    343
# 182            john nyabuto onyiego    ['M']   360138    191
# 183  milton stephen asike makhandia    ['M']  2344410   1340
# 184         stephen murugu githinji    ['M']   258021    173
# 185      hatari peter george waweru    ['M']  1451539   1562
# 186         mutungi charles kariuki    ['M']  1155878    573
# 187                     tom mbaluto    ['M']   218053    234
# 188          joseph kiplagat sergon    ['M']  2904611   2717
# 189            martha karambu koome    ['F']  1230406   1033
# 190               dorah o chepkwony    ['F']   312550    139
# 191           jessie wanjiku lessit    ['F']  1741387    968
# 192        beatrice thuranira jaden    ['F']   961920   1000
# 193                  antony ombwayo    ['M']  1511940    742
# 194          anthony ndung'u kimani    ['M']   510444    322
# 195          joseph raphael karanja    ['M']  1174166    749
# 196    samuel elikana ondari bosire    ['M']   194777    176
# 197          asenath nyaboke ongeri    ['F']   228933    104
# 198              patrick john kamau    ['M']   100857     74
# 199             fred andago ochieng    ['M']  2328783   1370

# %%
df_thresh[200:]
# Out:
#                           judge   gender   tokens  cases
# 200   thripsisa wanjiku cherere    ['F']   574626    506
# 201           festus azangalala    ['M']  1265838    944
# 202      nagillah chrispin beda    ['F']   309710    293
# 203        dalmas omondi ohungo    ['M']   403453    279
# 204      william kipsiro tuiyot    ['M']    88820     60
# 205        pamela mwikali tutui    ['F']    98538    138
# 206          enock chacha mwita    ['M']   981431    279
# 207          jesse nyagah njagi  ['UNK']   187721     82
# 208         abdulhalim h athman    ['M']    62141     52
# 209    roselyne ekirapa aburili    ['F']  3463528    764
# 210        john micheal khamoni    ['M']   748028    466
# 211               alfred mabeya    ['M']  1883797   1042
# 212  mathew john anyara emukule    ['M']  1877197    909
# 213    yuvinalis maronga angima    ['M']   444956    262
# 214           joel mwaura ngugi    ['M']   814452    354

# %%
len(df_temp)
# Out:
# 215
